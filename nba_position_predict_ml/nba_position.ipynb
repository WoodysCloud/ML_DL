# %%
nba = pd.read_csv('basket/basketball_stat.csv')

# %%
nba
# Out:
#               Player Pos   3P   2P   TRB  AST  STL  BLK
# 0       Alex Abrines  SG  1.4  0.6   1.3  0.6  0.5  0.1
# 1       Steven Adams   C  0.0  4.7   7.7  1.1  1.1  1.0
# 2      Alexis Ajinca   C  0.0  2.3   4.5  0.3  0.5  0.6
# 3     Chris Andersen   C  0.0  0.8   2.6  0.4  0.4  0.6
# 4        Will Barton  SG  1.5  3.5   4.3  3.4  0.8  0.5
# ..               ...  ..  ...  ...   ...  ...  ...  ...
# 95    Nikola Vucevic   C  0.3  6.1  10.4  2.8  1.0  1.0
# 96       Dwyane Wade  SG  0.8  6.2   4.5  3.8  1.4  0.7
# 97      Dion Waiters  SG  1.8  4.3   3.3  4.3  0.9  0.4
# 98  Hassan Whiteside   C  0.0  7.0  14.1  0.7  0.7  2.1
# 99      Lou Williams  SG  2.0  3.3   2.5  3.0  1.0  0.2
#
# [100 rows x 8 columns]

# %%
nba_ml = nba[['Player', 'Pos', '3P', 'TRB', 'BLK']]
nba_ml
# Out:
#               Player Pos   3P   TRB  BLK
# 0       Alex Abrines  SG  1.4   1.3  0.1
# 1       Steven Adams   C  0.0   7.7  1.0
# 2      Alexis Ajinca   C  0.0   4.5  0.6
# 3     Chris Andersen   C  0.0   2.6  0.6
# 4        Will Barton  SG  1.5   4.3  0.5
# ..               ...  ..  ...   ...  ...
# 95    Nikola Vucevic   C  0.3  10.4  1.0
# 96       Dwyane Wade  SG  0.8   4.5  0.7
# 97      Dion Waiters  SG  1.8   3.3  0.4
# 98  Hassan Whiteside   C  0.0  14.1  2.1
# 99      Lou Williams  SG  2.0   2.5  0.2
#
# [100 rows x 5 columns]

# %%
X = nba_ml[['3P', 'TRB', 'BLK']]
y = nba_ml[['Pos']]
X, y
# Out:
# (     3P   TRB  BLK
#  0   1.4   1.3  0.1
#  1   0.0   7.7  1.0
#  2   0.0   4.5  0.6
#  3   0.0   2.6  0.6
#  4   1.5   4.3  0.5
#  ..  ...   ...  ...
#  95  0.3  10.4  1.0
#  96  0.8   4.5  0.7
#  97  1.8   3.3  0.4
#  98  0.0  14.1  2.1
#  99  2.0   2.5  0.2
#
#  [100 rows x 3 columns],
#     Pos
#  0   SG
#  1    C
#  2    C
#  3    C
#  4   SG
#  ..  ..
#  95   C
#  96  SG
#  97  SG
#  98   C
#  99  SG
#
#  [100 rows x 1 columns])

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier

# %%
rf_clf = RandomForestClassifier(random_state=11)
lr_clf = LogisticRegression()
svm_svc1 = SVC()
svm_svc2 = SVC(kernel='linear')
knn = KNeighborsClassifier(n_neighbors=5)

# %%
from sklearn.model_selection import cross_val_score

clfs = [rf_clf, lr_clf, svm_svc1, svm_svc2, knn]
for clf in clfs:
    scores = cross_val_score(clf, X, y, cv=5) # cv: cross validation
    for iter_count,accuracy in enumerate(scores):
        print("교차 검증 {0} 정확도: {1:.4f}".format(iter_count, accuracy))
    print("{0} 평균 정확도: {1:.4f}\n".format(clf, np.mean(scores)))
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
# 학습데이터, 테스트데이터 분리
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size = 0.2, 
                                                    shuffle = True, 
                                                    random_state = 20)

# %%
X_train, X_test, y_train, y_test
# Out:
# (     3P   TRB  BLK
#  37  0.9   4.1  0.7
#  51  0.0  12.7  1.2
#  35  0.0  10.4  0.7
#  65  2.3   3.6  0.5
#  31  0.9   7.8  1.1
#  ..  ...   ...  ...
#  28  1.9   3.1  0.1
#  95  0.3  10.4  1.0
#  15  0.0   8.1  1.2
#  90  0.0   9.2  1.1
#  99  2.0   2.5  0.2
#
#  [80 rows x 3 columns],
#       3P   TRB  BLK
#  70  1.1   2.1  0.4
#  74  0.0   3.9  0.8
#  2   0.0   4.5  0.6
#  44  0.0   3.2  1.0
#  56  2.4   2.8  0.3
#  48  0.5   5.5  1.0
#  12  1.9   3.2  0.3
#  36  1.7   3.3  0.8
#  0   1.4   1.3  0.1
#  49  1.9   3.4  0.2
#  76  2.6   2.2  0.2
#  93  0.0   9.5  0.8
#  88  1.3   2.8  0.4
#  92  0.5   7.3  2.1
#  5   1.8   6.2  0.4
#  77  0.0   4.7  0.7
#  23  0.5  11.8  2.2
#  63  0.0   4.8  0.8
#  87  0.0   5.5  3.0
#  38  0.2   1.6  0.6,
#     Pos
#  37   C
#  51   C
#  35   C
#  65  SG
#  31   C
#  ..  ..
#  28  SG
#  95   C
#  15   C
#  90   C
#  99  SG
#
#  [80 rows x 1 columns],
#     Pos
#  70  SG
#  74   C
#  2    C
#  44   C
#  56  SG
#  48   C
#  12  SG
#  36  SG
# ...

# %%
# 최적의 파라미터 찾기
from sklearn.model_selection import GridSearchCV

# %%
rf_parameters = {'max_depth': [2, 3, 5, 10],
              'min_samples_split': [2, 3, 5], 
              'min_samples_leaf': [1, 5, 8]}

# %%
grid_dclf = GridSearchCV(rf_clf, param_grid=rf_parameters, scoring='accuracy', cv=5)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=11),
#              param_grid={'max_depth': [2, 3, 5, 10],
#                          'min_samples_leaf': [1, 5, 8],
#                          'min_samples_split': [2, 3, 5]},
#              scoring='accuracy')

# %%
grid_dclf.fit(X_train, y_train)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
best_dclf = grid_dclf.best_estimator_
# Out:
# RandomForestClassifier(max_depth=3, random_state=11)

# %%
best_params = grid_dclf.best_params_
# Out:
# {'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 2}

# %%
best_score = grid_dclf.best_score_
# Out:
# 0.95

# %%
pred = best_dclf.predict(X_test)
# Out:
# array(['SG', 'C', 'C', 'C', 'SG', 'C', 'SG', 'SG', 'SG', 'SG', 'SG', 'C',
#        'SG', 'C', 'SG', 'C', 'C', 'C', 'C', 'C'], dtype=object)

# %%
accuracy = accuracy_score(y_test, pred)
accuracy
# Out:
# 1.0
